# %%
# !pip install langchain_groq langchain_core langchain_community
# Out:
# ...
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# ...

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    temperature = 0,
    groq_api_key = "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",
    model_name = "llama-3.3-70b-versatile"
)
result = llm.invoke("Who is lord Ram?")
print(result.content)
# Out:
# Lord Rama is a major deity in Hinduism and is considered one of the most revered and beloved figures in Hindu mythology. He is the seventh avatar (incarnation) of Lord Vishnu, the preserver of the universe, and is often referred to as "Maryada Purushottam" or "the perfect man."
#
# According to the Hindu epic, the Ramayana, Lord Rama was born in the city of Ayodhya, in the kingdom of Kosala, to King Dasharatha and Queen Kausalya. He was the eldest of four brothers, including Lakshmana, Bharata, and Shatrughna.
#
# Lord Rama is known for his exceptional virtues, such as:
#
# 1. **Dharma** (righteousness): He was a strict follower of dharma and always adhered to the principles of truth, justice, and morality.
# 2. **Bravery**: He was a skilled warrior and demonstrated extraordinary courage in the face of adversity.
# 3. **Compassion**: He was known for his kindness, empathy, and generosity towards all living beings.
# ...

# %%
# !pip install pypdf

# %%
# !pip install chromadb
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 4.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 4.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 5.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.8 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53800 sha256=2a3d9e649d381dada3c48e9cff689dadf9d46c57595ba8f62fb75c64813aba5a
#   Stored in directory: /Users/pg/Library/Caches/pip/wheels/d5/3d/69/8d68d249cd3de2584f226e27fd431d6344f7d70fd856ebd01b
# Successfully built pypika
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 4.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 6.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 5.6 MB/s eta 0:00:00 0:00:01
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# ...

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
def initialize_llm():
  llm = ChatGroq(
    temperature = 0,
    groq_api_key = "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",
    model_name = "llama-3.3-70b-versatile"
)
  return llm

def create_vector_db():
  loader = DirectoryLoader("./data", glob = '*.pdf', loader_cls = PyPDFLoader)
  documents = loader.load()
  text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)
  texts = text_splitter.split_documents(documents)
  embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
  vector_db = Chroma.from_documents(texts, embeddings, persist_directory = './chroma_db')
  vector_db.persist()

  print("ChromaDB created and data saved")

  return vector_db

def setup_qa_chain(vector_db, llm):
  retriever = vector_db.as_retriever()
  prompt_templates = """ You are a compassionate mental health chatbot. Respond thoughtfully to the following question:
    {context}
    User: {question}
    Chatbot: """
  PROMPT = PromptTemplate(template = prompt_templates, input_variables = ['context', 'question'])

  qa_chain = RetrievalQA.from_chain_type(
      llm = llm,
      chain_type = "stuff",
      retriever = retriever,
      chain_type_kwargs = {"prompt": PROMPT}
  )
  return qa_chain


def main():
  print("Intializing Chatbot.........")
  llm = initialize_llm()

  db_path = "/content/chroma_db"

  if not os.path.exists(db_path):
    vector_db  = create_vector_db()
  else:
    embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
    vector_db = Chroma(persist_directory=db_path, embedding_function=embeddings)
  qa_chain = setup_qa_chain(vector_db, llm)

  while True:
    query = input("\nHuman: ")
    if query.lower()  == "exit":
      print("Chatbot: Take Care of yourself, Goodbye!")
      break
    response = qa_chain.run(query)
    print(f"Chatbot: {response}")

if __name__ == "__main__":
  main()
# Out:
# Intializing Chatbot.........
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 68
#      65     print(f"Chatbot: {response}")
#      67 if __name__ == "__main__":
# ---> 68   main()
#
# Cell In[12], line 53, in main()
#      50 db_path = "/content/chroma_db"
#      52 if not os.path.exists(db_path):
# ---> 53   vector_db  = create_vector_db()
#      54 else:
#      55   embeddings = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
#
# Cell In[12], line 18, in create_vector_db()
#      16 def create_vector_db():
#      17   loader = DirectoryLoader("./data", glob = '*.pdf', loader_cls = PyPDFLoader)
# ---> 18   documents = loader.load()
#      19   text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)
#      20   texts = text_splitter.split_documents(documents)
#
# ...

# %%
# !pip install gradio

# %%
# Install dependencies before running the script
# !pip install langchain_groq langchain_core langchain_community pypdf chromadb sentence_transformers gradio

import os
from langchain_groq import ChatGroq
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
import gradio as gr

# Hardcoded API Key (⚠️ Not recommended for production)
GROQ_API_KEY = "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"

# Initialize LLM
def initialize_llm():
    return ChatGroq(
        temperature=0,
        groq_api_key=GROQ_API_KEY,
        model_name="llama-3.3-70b-versatile"
    )

# Create or Load ChromaDB
def create_vector_db():
    loader = DirectoryLoader("./data/", glob="*.pdf", loader_cls=PyPDFLoader)
    documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    texts = text_splitter.split_documents(documents)

    embeddings = HuggingFaceBgeEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    vector_db = Chroma.from_documents(texts, embeddings, persist_directory="./chroma_db")
    vector_db.persist()

    print("✅ ChromaDB created and data saved")
    return vector_db

# Setup QA Chain
def setup_qa_chain(vector_db, llm):
    retriever = vector_db.as_retriever()
    prompt_template = """You are a compassionate mental health chatbot. Respond thoughtfully to the following question:
    {context}
    User: {question}
    Chatbot: """

    PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

    return RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        chain_type_kwargs={"prompt": PROMPT}
    )

# Initialize Chatbot
print("🧠 Initializing Chatbot...")
llm = initialize_llm()
db_path = "./chroma_db"

if not os.path.exists(db_path):
    vector_db = create_vector_db()
else:
    embeddings = HuggingFaceBgeEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    vector_db = Chroma(persist_directory=db_path, embedding_function=embeddings)

qa_chain = setup_qa_chain(vector_db, llm)

# Gradio Chatbot Function
def chatbot_response(user_input, history=[]):
    if not user_input.strip():
        return "⚠️ Please provide a valid input.", history

    try:
        response = qa_chain.run(user_input) or "I'm not sure how to respond. Can you clarify?"
    except Exception as e:
        response = f"⚠️ Error: {str(e)}"

    history.append((user_input, response))
    return "", history

# Launch Gradio Interface
with gr.Blocks(theme="Respair/Shiki@1.2.1") as app:
    gr.Markdown("# 🧠 Mental Health Chatbot 🤖")
    gr.Markdown("A compassionate chatbot designed to assist with mental well-being. **For serious concerns, contact a professional.**")

    chatbot = gr.Chatbot()
    input_text = gr.Textbox(placeholder="Type your message here...")
    submit_btn = gr.Button("Send")

    def on_submit(text, history):
        return chatbot_response(text, history)

    submit_btn.click(on_submit, [input_text, chatbot], [input_text, chatbot])

    gr.Markdown("⚠️ This chatbot provides general support. **For urgent issues, seek help from licensed professionals.**")

app.launch()
